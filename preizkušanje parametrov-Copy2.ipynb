# %%
sys
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-7a51ce427d93> in <module>
# ----> 1 sys
#
# NameError: name 'sys' is not defined

# %%
import sys

# %%
sys.path
# Out:
# ['C:\\Users\\Neža',
#  'C:\\Users\\Neža\\Documents\\GitHub\\GA-on-TSP',
#  'C:\\Users\\Neža',
#  'c:\\users\\neža\\appdata\\local\\programs\\python\\python37-32\\python37.zip',
#  'c:\\users\\neža\\appdata\\local\\programs\\python\\python37-32\\DLLs',
#  'c:\\users\\neža\\appdata\\local\\programs\\python\\python37-32\\lib',
#  'c:\\users\\neža\\appdata\\local\\programs\\python\\python37-32',
#  '',
#  'c:\\users\\neža\\appdata\\local\\programs\\python\\python37-32\\lib\\site-packages',
#  'c:\\users\\neža\\appdata\\local\\programs\\python\\python37-32\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\Neža\\.ipython']

# %%
import projektOR as pr
import matplotlib.pyplot as plt

# %%
data = "kroa100.txt"
dataPot = "kroa100opt.txt"
    
lokacije = pr.preberi(data)
razdalje = pr.mesta(lokacije)
najkrajsa = pr.najkrajsaConcord(dataPot)

# %%
pr.dolzinaPoti(najkrajsa, razdalje)
pr.narisi(najkrajsa, lokacije)

# %%
pr.dolzinaPoti(najkrajsa, razdalje)
# Out:
# 21285.44318157108

# %% [markdown]
# Preizkusimo vrednosti različnih parametrov za primer "kroa100", pri crossover metodi OX

# %%
CO = "OX"
k_turnir = 5
verj_mutacije = 0.005

# %% [markdown]
# Zgornji argumenti ostajajo fiksni, menjamo le število generacij (100, 1000) in velikost populacije (20, 100):

# %%
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 47316.20466279582

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 36408.74108684091

# %%
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 89624.9390040434

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 64058.945006051

# %% [markdown]
# Enak postopek naredimo še za primer "ulysses22":

# %%
data = "ulysses22.txt"
dataPot = "ulysses22opt.txt"
    
lokacije = pr.preberi(data)
razdalje = pr.mestaGeo(lokacije)
najkrajsa = pr.najkrajsaConcord(dataPot)

# %%
pr.narisi(najkrajsa, lokacije)

# %%
pr.dolzinaPoti(najkrajsa, razdalje)
# Out:
# 7013.0

# %%
CO = "OX"
k_turnir = 5
verj_mutacije = 0.005

# %%
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 8478.0

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 7112.0

# %%
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 8273.0

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 7314.0

# %% [markdown]
# Različne parametre preizkusimo tudi na tretjem problemu "berlin52", kjer dodamo še vsa tri možna križanja in algoritme ponavljamo po 20-krat:

# %%
data = "berlin52.txt"
dataPot = "berlin52opt.txt"
    
lokacije = pr.preberi(data)
razdalje = pr.mesta(lokacije)
najkrajsa = pr.najkrajsaConcord(dataPot)

# %%
pr.narisi(najkrajsa, lokacije)

# %%
pr.dolzinaPoti(najkrajsa, razdalje)
# Out:
# 7544.365901904087

# %%
st_ponovitev = 20
k_turnir = 5

# %% [markdown]
# Fiksna v tem primeru ostajata zgornja dva argumenta, spreminjamo pa verjetnost mutacije (0, 0.005, 0.04), velikost populacije (20, 100), število generacij (100, 1000) in vrsto metode križanja (CX, PMX, OX):

# %% [markdown]
# Začnemo z metodo CX:

# %%
CO = "CX"
verj_mutacije = 0
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat[1][0], razdalje)))
pr.narisi(rezultat[1][0], lokacije)
# Out:
# Dolžina najkrajše poti: 24365.538857518306

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)

# %%
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0, k_turnir, CO)

# %%
print("Dolžina povprecne poti: " + str(rezultat[0]))
# Out:
# Dolžina povprecne poti: 26534.386133688513

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0, k_turnir, CO)
print("Dolžina povprecne poti: " + str(rezultat[0]))
# Out:
# Dolžina povprecne poti: 22651.140301212443

# %%
CO = "CX"
verj_mutacije = 0
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0, k_turnir, CO)
print("Dolžina povprecne poti: " + str(rezultat[0]))
# Out:
# Dolžina povprecne poti: 26041.29701082712

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0, k_turnir, CO)
print("Dolžina povprecne poti: " + str(rezultat[0]))
# Out:
# Dolžina najkrajše poti: 19586.957717645524

# %% [markdown]
# Verjetnost mutacije spremenimo na 0.005 in postopek ponovimo:

# %%
CO = "CX"
verj_mutacije = 0.005
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina povprecne poti: " + str(rezultat[0]))
# Out:
# Dolžina povprecne poti: 16299.501643809452

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina povprecne poti: " + str(rezultat[0]))
# Out:
# Dolžina povprecne poti: 12288.17850413282

# %%
CO = "CX"
verj_mutacije = 0.005
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina povprecne poti: " + str(rezultat[0]))
# Out:
# Dolžina povprecne poti: 11094.163735623539

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina povprecne poti: " + str(rezultat[0]))
# Out:
# Dolžina povprecne poti: 10517.251421476773

# %% [markdown]
# Vzamemo še tretjo verjetnost mutacije, in sicer 0.04:

# %%
CO = "CX"
verj_mutacije = 0.04
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0.04, k_turnir, CO)
print("Dolžina povprecne poti: " + str(rezultat[0]))
# Out:
# Dolžina povprecne poti: 16690.240057970736

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0.04, k_turnir, CO)
print("Dolžina povprecne poti: " + str(rezultat[0]))
# Out:
# Dolžina povprecne poti: 14140.060403771382

# %%
CO = "CX"
verj_mutacije = 0.04
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0.04, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat[1][0], razdalje)))
pr.narisi(rezultat[1][0], lokacije)
# Out:
# Dolžina najkrajše poti: 14036.700146814099

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0.04, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat[1][0], razdalje)))
pr.narisi(rezultat[1][0], lokacije)
# Out:
# Dolžina najkrajše poti: 10842.375549131126

# %% [markdown]
# Zaključili smo s preizkušanjem argumentov na metodi CX, kot naslednjo vzemimo PMX:

# %%
CO = "PMX"
verj_mutacije = 0
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0, k_turnir, CO)
print("Dolžina povprecne poti: " + str(rezultat[0]))
# Out:
# Dolžina povprecne poti: 23745.06126978455

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0, k_turnir, CO)
print("Dolžina povprecne poti: " + str(rezultat[0]))
# Out:
# Dolžina povprecne poti: 18145.602894249292

# %%
CO = "PMX"
verj_mutacije = 0
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat[1][0], razdalje)))
pr.narisi(rezultat[1][0], lokacije)
# Out:
# Dolžina najkrajše poti: 20544.05708541531

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat[1][0], razdalje)))
pr.narisi(rezultat[1][0], lokacije)
# Out:
# Dolžina najkrajše poti: 15011.00933941573

# %% [markdown]
# Verjetnost mutacije zopet zamenjamo:

# %%
CO = "PMX"
verj_mutacije = 0.005
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina povprecne poti: " + str(rezultat[0]))
# Out:
# Dolžina povprecne poti: 15785.292047855473

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina povprecne poti: " + str(rezultat[0]))
# Out:
# Dolžina povprecne poti: 12234.07433578062

# %%
CO = "PMX"
verj_mutacije = 0.005
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina povprecne poti: " + str(rezultat[0]))
# Out:
# Dolžina povprecne poti: 11155.965572798623

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina povprecne poti: " + str(rezultat[0]))
# Out:
# Dolžina povprecne poti: 10094.514171434128

# %% [markdown]
# Vzamemo še tretjo verjetnost mutacije:

# %%
CO = "PMX"
verj_mutacije = 0.04
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0.04, k_turnir, CO)
print("Dolžina povprecne poti: " + str(rezultat[0]))
# Out:
# Dolžina povprecne poti: 17078.4177069776

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0.04, k_turnir, CO)
print("Dolžina povprecne poti: " + str(rezultat[0]))
# Out:
# Dolžina povprecne poti: 14991.205890451649

# %%
CO = "PMX"
verj_mutacije = 0.04
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0.04, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat[1][0], razdalje)))
pr.narisi(rezultat[1][0], lokacije)
# Out:
# Dolžina najkrajše poti: 14118.735181279462

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0.04, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat[1][0], razdalje)))
pr.narisi(rezultat[1][0], lokacije)
# Out:
# Dolžina najkrajše poti: 12848.075909937765

# %% [markdown]
# Celoten postopek ponovimo še na tretji metodi, OX:

# %%
CO = "OX"
verj_mutacije = 0
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0, k_turnir, CO)
print("Dolžina povprecne poti: " + str(rezultat[0]))
# Out:
# Dolžina povprecne poti: 21669.221695136413

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0, k_turnir, CO)
print("Dolžina povprecne poti: " + str(rezultat[0]))
# Out:
# Dolžina povprecne poti: 11297.248994620775

# %%
CO = "OX"
verj_mutacije = 0
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat[1][0], razdalje)))
pr.narisi(rezultat[1][0], lokacije)
# Out:
# Dolžina najkrajše poti: 18924.0203019158

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat[1][0], razdalje)))
pr.narisi(rezultat[1][0], lokacije)
# Out:
# Dolžina najkrajše poti: 10235.348658635436

# %% [markdown]
# Menjamo vrednost mutacije na 0.005:

# %%
CO = "OX"
verj_mutacije = 0.005
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina povprecne poti: " + str(rezultat[0]))
# Out:
# Dolžina povprecne poti: 15863.165494447447

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina povprecne poti: " + str(rezultat[0]))
# Out:
# Dolžina povprecne poti: 11078.454546881352

# %%
CO = "OX"
verj_mutacije = 0.005
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina povprecne poti: " + str(rezultat[0]))
# Out:
# Dolžina povprecne poti: 10937.908677280444

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina povprecne poti: " + str(rezultat[0]))
# Out:
# Dolžina povprecne poti: 9487.161492624531

# %% [markdown]
# Še zadnja verjetnost mutacije:

# %%
CO = "OX"
verj_mutacije = 0.04
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0.04, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat[1][0], razdalje)))
pr.narisi(rezultat[1][0], lokacije)
# Out:
# Dolžina najkrajše poti: 18324.84436499578

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0.04, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat[1][0], razdalje)))
pr.narisi(rezultat[1][0], lokacije)
# Out:
# Dolžina najkrajše poti: 15168.55676781616

# %%
CO = "OX"
verj_mutacije = 0.04
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0.04, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat[1][0], razdalje)))
pr.narisi(rezultat[1][0], lokacije)
# Out:
# Dolžina najkrajše poti: 16656.291660627812

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0.04, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat[1][0], razdalje)))
pr.narisi(rezultat[1][0], lokacije)
# Out:
# Dolžina najkrajše poti: 16360.09758131356
