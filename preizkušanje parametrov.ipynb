# %%
import projektOR as pr
import matplotlib.pyplot as plt

# %%
data = "kroa100.txt"
dataPot = "kroa100opt.txt"
    
lokacije = pr.preberi(data)
razdalje = pr.mesta(lokacije)
najkrajsa = pr.najkrajsaConcord(dataPot)

# %%
pr.dolzinaPoti(najkrajsa, razdalje)
pr.narisi(najkrajsa, lokacije)

# %%
pr.dolzinaPoti(najkrajsa, razdalje)
# Out:
# 21285.44318157108

# %% [markdown]
# Preizkusimo vrednosti različnih parametrov za primer "kroa100", pri crossover metodi OX

# %%
CO = "OX"
k_turnir = 5
verj_mutacije = 0.005

# %% [markdown]
# Zgornji argumenti ostajajo fiksni, menjamo le število generacij (100, 1000) in velikost populacije (20, 100):

# %%
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 48555.3626507777

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 35004.91526522913

# %%
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 85351.07548842921

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 62000.52110017255

# %% [markdown]
# Enak postopek naredimo še za primer "ulysses22":

# %%
data = "ulysses22.txt"
dataPot = "ulysses22opt.txt"
    
lokacije = pr.preberi(data)
razdalje = pr.mestaGeo(lokacije)
najkrajsa = pr.najkrajsaConcord(dataPot)

# %%
pr.narisi(najkrajsa, lokacije)

# %%
pr.dolzinaPoti(najkrajsa, razdalje)
# Out:
# 7013.0

# %%
CO = "OX"
k_turnir = 5
verj_mutacije = 0.005

# %%
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 7897.0

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 7087.0

# %%
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 8362.0

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 7013.0

# %% [markdown]
# Različne parametre preizkusimo tudi na tretjem problemu "berlin52", kjer dodamo še vsa tri možna križanja in algoritme ponavljamo po 20-krat:

# %%
data = "berlin52.txt"
dataPot = "berlin52opt.txt"
    
lokacije = pr.preberi(data)
razdalje = pr.mesta(lokacije)
najkrajsa = pr.najkrajsaConcord(dataPot)

# %%
pr.narisi(najkrajsa, lokacije)

# %%
pr.dolzinaPoti(najkrajsa, razdalje)
# Out:
# 7544.365901904087

# %%
st_ponovitev = 20
k_turnir = 5

# %% [markdown]
# Fiksna v tem primeru ostajata zgornja dva argumenta, spreminjamo pa verjetnost mutacije (0, 0.005, 0.04), velikost populacije (20, 100), število generacij (100, 1000) in vrsto metode križanja (CX, PMX, OX):

# %% [markdown]
# Začnemo z metodo CX:

# %%
CO = "CX"
verj_mutacije = 0
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 15824.560324200136

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 12251.125991184495

# %%
CO = "CX"
verj_mutacije = 0
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 10267.845549330632

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 9688.84774092788

# %% [markdown]
# Verjetnost mutacije spremenimo na 0.005 in postopek ponovimo:

# %%
CO = "CX"
verj_mutacije = 0.005
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 16070.402562478219

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 13002.325603754172

# %%
CO = "CX"
verj_mutacije = 0.005
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 11405.330559000178

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 13106.190276488172

# %% [markdown]
# Vzamemo še tretjo verjetnost mutacije, in sicer 0.04:

# %%
CO = "CX"
verj_mutacije = 0.004
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 15817.278414666585

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 13408.75432947472

# %%
CO = "CX"
verj_mutacije = 0.004
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 11658.898197543038

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 11188.467258868553

# %% [markdown]
# Zaključili smo s preizkušanjem argumentov na metodi CX, kot naslednjo vzemimo PMX:

# %%
CO = "PMX"
verj_mutacije = 0
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 16191.906276570226

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 12905.93449071687

# %%
CO = "PMX"
verj_mutacije = 0
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 10975.14945752254

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 10698.600306797554

# %% [markdown]
# Verjetnost mutacije zopet zamenjamo:

# %%
CO = "PMX"
verj_mutacije = 0.005
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 17298.07740054786

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 11157.489380021489

# %%
CO = "PMX"
verj_mutacije = 0.005
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 12738.716019608504

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 10258.805169306966

# %% [markdown]
# Vzamemo še tretjo verjetnost mutacije:

# %%
CO = "PMX"
verj_mutacije = 0.04
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 15427.87933725688

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 12381.35424676053

# %%
CO = "PMX"
verj_mutacije = 0.04
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 11631.837776542185

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 10859.299853625773

# %% [markdown]
# Celoten postopek ponovimo še na tretji metodi, OX:

# %%
CO = "OX"
verj_mutacije = 0
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 15448.737150861047

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 10105.753089712905

# %%
CO = "OX"
verj_mutacije = 0
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 11533.330179312889

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 9651.191336201764

# %% [markdown]
# Menjamo vrednost mutacije na 0.005:

# %%
CO = "OX"
verj_mutacije = 0.005
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 14068.67497055583

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 11009.625617641654

# %%
CO = "OX"
verj_mutacije = 0.005
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 10119.704890943764

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 9168.290274410578

# %% [markdown]
# Še zadnja verjetnost mutacije:

# %%
CO = "OX"
verj_mutacije = 0.04
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 14872.644878217538

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 12246.077349122505

# %%
CO = "OX"
verj_mutacije = 0.04
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 11079.723688414415

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 9156.670341572266
