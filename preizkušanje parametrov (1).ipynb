# %%
sys
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7a51ce427d93> in <module>
# ----> 1 sys
#
# NameError: name 'sys' is not defined

# %%
import sys

# %%
sys.path
# Out:
# ['C:\\Users\\Neža',
#  'C:\\Users\\Neža\\Documents\\GitHub\\GA-on-TSP',
#  'C:\\Users\\Neža',
#  'c:\\users\\neža\\appdata\\local\\programs\\python\\python37-32\\python37.zip',
#  'c:\\users\\neža\\appdata\\local\\programs\\python\\python37-32\\DLLs',
#  'c:\\users\\neža\\appdata\\local\\programs\\python\\python37-32\\lib',
#  'c:\\users\\neža\\appdata\\local\\programs\\python\\python37-32',
#  '',
#  'c:\\users\\neža\\appdata\\local\\programs\\python\\python37-32\\lib\\site-packages',
#  'c:\\users\\neža\\appdata\\local\\programs\\python\\python37-32\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\Neža\\.ipython']

# %%
import projektOR as pr
import matplotlib.pyplot as plt

# %%
data = "kroa100.txt"
dataPot = "kroa100opt.txt"
    
lokacije = pr.preberi(data)
razdalje = pr.mesta(lokacije)
najkrajsa = pr.najkrajsaConcord(dataPot)

# %%
pr.dolzinaPoti(najkrajsa, razdalje)
pr.narisi(najkrajsa, lokacije)

# %%
pr.dolzinaPoti(najkrajsa, razdalje)
# Out:
# 21285.44318157108

# %% [markdown]
# Preizkusimo vrednosti različnih parametrov za primer "kroa100", pri crossover metodi OX

# %%
CO = "OX"
k_turnir = 5
verj_mutacije = 0.005

# %% [markdown]
# Zgornji argumenti ostajajo fiksni, menjamo le število generacij (100, 1000) in velikost populacije (20, 100):

# %%
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 48158.58933371546

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 39058.78341505736

# %%
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 88252.27661072045

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 66572.07267622728

# %% [markdown]
# Enak postopek naredimo še za primer "ulysses22":

# %%
data = "ulysses22.txt"
dataPot = "ulysses22opt.txt"
    
lokacije = pr.preberi(data)
razdalje = pr.mestaGeo(lokacije)
najkrajsa = pr.najkrajsaConcord(dataPot)

# %%
pr.narisi(najkrajsa, lokacije)

# %%
pr.dolzinaPoti(najkrajsa, razdalje)
# Out:
# 7013.0

# %%
CO = "OX"
k_turnir = 5
verj_mutacije = 0.005

# %%
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 7856.0

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 7171.0

# %%
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 8170.0

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 7092.0

# %% [markdown]
# Različne parametre preizkusimo tudi na tretjem problemu "berlin52", kjer dodamo še vsa tri možna križanja in algoritme ponavljamo po 20-krat:

# %%
data = "berlin52.txt"
dataPot = "berlin52opt.txt"
    
lokacije = pr.preberi(data)
razdalje = pr.mesta(lokacije)
najkrajsa = pr.najkrajsaConcord(dataPot)

# %%
pr.narisi(najkrajsa, lokacije)

# %%
pr.dolzinaPoti(najkrajsa, razdalje)
# Out:
# 7544.365901904087

# %%
st_ponovitev = 20
k_turnir = 5

# %% [markdown]
# Fiksna v tem primeru ostajata zgornja dva argumenta, spreminjamo pa verjetnost mutacije (0, 0.005, 0.04), velikost populacije (20, 100), število generacij (100, 1000) in vrsto metode križanja (CX, PMX, OX):

# %% [markdown]
# Začnemo z metodo CX:

# %%
CO = "CX"
verj_mutacije = 0
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 26902.576557203567

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 21407.024018116048

# %%
CO = "CX"
verj_mutacije = 0
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 26393.46308299308

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 21018.757816314916

# %% [markdown]
# Verjetnost mutacije spremenimo na 0.005 in postopek ponovimo:

# %%
CO = "CX"
verj_mutacije = 0.005
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 15527.399742726637

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 13542.618656259134

# %%
CO = "CX"
verj_mutacije = 0.005
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 11020.72864840673

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 9469.786875975991

# %% [markdown]
# Vzamemo še tretjo verjetnost mutacije, in sicer 0.04:

# %%
CO = "CX"
verj_mutacije = 0.04
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.04, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 16354.858588805528

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.04, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 14487.022522412188

# %%
CO = "CX"
verj_mutacije = 0.04
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.04, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 16056.289889348584

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.04, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 11820.355197034141

# %% [markdown]
# Zaključili smo s preizkušanjem argumentov na metodi CX, kot naslednjo vzemimo PMX:

# %%
CO = "PMX"
verj_mutacije = 0
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 25443.225873667372

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 15580.976060411982

# %%
CO = "PMX"
verj_mutacije = 0
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 22821.365214483983

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 16946.740908283497

# %% [markdown]
# Verjetnost mutacije zopet zamenjamo:

# %%
CO = "PMX"
verj_mutacije = 0.005
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 17890.20079411914

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 11778.296596020518

# %%
CO = "PMX"
verj_mutacije = 0.005
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 12593.822825151241

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 10536.57024120405

# %% [markdown]
# Vzamemo še tretjo verjetnost mutacije:

# %%
CO = "PMX"
verj_mutacije = 0.04
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.04, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 16244.28211403806

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.04, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 15220.561133963061

# %%
CO = "PMX"
verj_mutacije = 0.04
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.04, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 17365.884429937676

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.04, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 12827.84570742682

# %% [markdown]
# Celoten postopek ponovimo še na tretji metodi, OX:

# %%
CO = "OX"
verj_mutacije = 0
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 24248.56812119144

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 10587.49858446589

# %%
CO = "OX"
verj_mutacije = 0
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 24282.70253242455

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 12321.32107975693

# %% [markdown]
# Menjamo vrednost mutacije na 0.005:

# %%
CO = "OX"
verj_mutacije = 0.005
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 14766.643665940068

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 10627.15471182965

# %%
CO = "OX"
verj_mutacije = 0.005
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 9925.877049780369

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 9719.221685226204

# %% [markdown]
# Še zadnja verjetnost mutacije:

# %%
CO = "OX"
verj_mutacije = 0.04
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.04, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 20040.79014567967

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.04, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 19048.969548191173

# %%
CO = "OX"
verj_mutacije = 0.04
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.04, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 18915.9166693115

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.04, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 19577.33892061774
