# %%
sys
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7a51ce427d93> in <module>
# ----> 1 sys
#
# NameError: name 'sys' is not defined

# %%
import sys

# %%
sys.path
# Out:
# ['C:\\Users\\Neža',
#  'C:\\Users\\Neža\\Documents\\GitHub\\GA-on-TSP',
#  'C:\\Users\\Neža',
#  'c:\\users\\neža\\appdata\\local\\programs\\python\\python37-32\\python37.zip',
#  'c:\\users\\neža\\appdata\\local\\programs\\python\\python37-32\\DLLs',
#  'c:\\users\\neža\\appdata\\local\\programs\\python\\python37-32\\lib',
#  'c:\\users\\neža\\appdata\\local\\programs\\python\\python37-32',
#  '',
#  'c:\\users\\neža\\appdata\\local\\programs\\python\\python37-32\\lib\\site-packages',
#  'c:\\users\\neža\\appdata\\local\\programs\\python\\python37-32\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\Neža\\.ipython']

# %%
import projektOR as pr
import matplotlib.pyplot as plt

# %%
data = "kroa100.txt"
dataPot = "kroa100opt.txt"
    
lokacije = pr.preberi(data)
razdalje = pr.mesta(lokacije)
najkrajsa = pr.najkrajsaConcord(dataPot)

# %%
pr.dolzinaPoti(najkrajsa, razdalje)
pr.narisi(najkrajsa, lokacije)

# %%
pr.dolzinaPoti(najkrajsa, razdalje)
# Out:
# 21285.44318157108

# %% [markdown]
# Preizkusimo vrednosti različnih parametrov za primer "kroa100", pri crossover metodi OX

# %%
CO = "OX"
k_turnir = 5
verj_mutacije = 0.005

# %% [markdown]
# Zgornji argumenti ostajajo fiksni, menjamo le število generacij (100, 1000) in velikost populacije (20, 100):

# %%
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 52847.97959527456

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 33785.78200302515

# %%
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 88344.42858956926

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 69868.47844689962

# %% [markdown]
# Enak postopek naredimo še za primer "ulysses22":

# %%
data = "ulysses22.txt"
dataPot = "ulysses22opt.txt"
    
lokacije = pr.preberi(data)
razdalje = pr.mestaGeo(lokacije)
najkrajsa = pr.najkrajsaConcord(dataPot)

# %%
pr.narisi(najkrajsa, lokacije)

# %%
pr.dolzinaPoti(najkrajsa, razdalje)
# Out:
# 7013.0

# %%
CO = "OX"
k_turnir = 5
verj_mutacije = 0.005

# %%
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 8429.0

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 7126.0

# %%
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 8616.0

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 7354.0

# %% [markdown]
# Različne parametre preizkusimo tudi na tretjem problemu "berlin52", kjer dodamo še vsa tri možna križanja in algoritme ponavljamo po 20-krat:

# %%
data = "berlin52.txt"
dataPot = "berlin52opt.txt"
    
lokacije = pr.preberi(data)
razdalje = pr.mesta(lokacije)
najkrajsa = pr.najkrajsaConcord(dataPot)

# %%
pr.narisi(najkrajsa, lokacije)

# %%
pr.dolzinaPoti(najkrajsa, razdalje)
# Out:
# 7544.365901904087

# %%
st_ponovitev = 20
k_turnir = 5

# %% [markdown]
# Fiksna v tem primeru ostajata zgornja dva argumenta, spreminjamo pa verjetnost mutacije (0, 0.005, 0.04), velikost populacije (20, 100), število generacij (100, 1000) in vrsto metode križanja (CX, PMX, OX):

# %% [markdown]
# Začnemo z metodo CX:

# %%
CO = "CX"
verj_mutacije = 0
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 23322.331820426236

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 17852.523827221612

# %%
CO = "CX"
verj_mutacije = 0
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 24119.77881068364

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 18631.711034807726

# %% [markdown]
# Verjetnost mutacije spremenimo na 0.005 in postopek ponovimo:

# %%
CO = "CX"
verj_mutacije = 0.005
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 17090.786139948592

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 12708.886416207994

# %%
CO = "CX"
verj_mutacije = 0.005
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 12077.853821054343

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 11256.967887156768

# %% [markdown]
# Vzamemo še tretjo verjetnost mutacije, in sicer 0.04:

# %%
CO = "CX"
verj_mutacije = 0.04
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.04, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 16481.492121184583

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.04, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 13688.804148490413

# %%
CO = "CX"
verj_mutacije = 0.04
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.04, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 14502.641019811714

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.04, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 12179.503072077763

# %% [markdown]
# Zaključili smo s preizkušanjem argumentov na metodi CX, kot naslednjo vzemimo PMX:

# %%
CO = "PMX"
verj_mutacije = 0
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 24049.501167283113

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 16625.05131925259

# %%
CO = "PMX"
verj_mutacije = 0
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 21557.17357543982

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 17505.64176668046

# %% [markdown]
# Verjetnost mutacije zopet zamenjamo:

# %%
CO = "PMX"
verj_mutacije = 0.005
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 15055.483268222351

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 11549.383419691907

# %%
CO = "PMX"
verj_mutacije = 0.005
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 11249.281382431613

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 9496.697400073288

# %% [markdown]
# Vzamemo še tretjo verjetnost mutacije:

# %%
CO = "PMX"
verj_mutacije = 0.04
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.04, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 17688.80642525683

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.04, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 16288.679385322206

# %%
CO = "PMX"
verj_mutacije = 0.04
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.04, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 17972.702298959157

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.04, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 12516.43777414343

# %% [markdown]
# Celoten postopek ponovimo še na tretji metodi, OX:

# %%
CO = "OX"
verj_mutacije = 0
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 23916.070545973416

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 12655.689525374557

# %%
CO = "OX"
verj_mutacije = 0
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 21371.338060809794

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 10813.711158190952

# %% [markdown]
# Menjamo vrednost mutacije na 0.005:

# %%
CO = "OX"
verj_mutacije = 0.005
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 15353.37262500424

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 10903.242407433081

# %%
CO = "OX"
verj_mutacije = 0.005
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 11530.15797090622

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 8763.631072190237

# %% [markdown]
# Še zadnja verjetnost mutacije:

# %%
CO = "OX"
verj_mutacije = 0.04
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.04, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 18238.425289578612

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.04, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 17497.520373563202

# %%
CO = "OX"
verj_mutacije = 0.04
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.04, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 18246.7451527485

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.04, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 17471.820618605925
