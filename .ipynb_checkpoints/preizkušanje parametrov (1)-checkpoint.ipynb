# %%
import projektOR as pr
import matplotlib.pyplot as plt

# %%
data = "kroa100.txt"
dataPot = "kroa100opt.txt"
    
lokacije = pr.preberi(data)
razdalje = pr.mesta(lokacije)
najkrajsa = pr.najkrajsaConcord(dataPot)

# %% [markdown]
# Graf in dolžina najkrajše poti za primer **kroa100**, dobljen s TSP Concord Solverjem:

# %%
pr.dolzinaPoti(najkrajsa, razdalje)
pr.narisi(najkrajsa, lokacije)

# %%
pr.dolzinaPoti(najkrajsa, razdalje)
# Out:
# 21285.44318157108

# %% [markdown]
# Preizkusimo vrednosti različnih parametrov za primer **kroa100**, pri crossover metodi **OX**:

# %%
CO = "OX"
k_turnir = 5
verj_mutacije = 0.005

# %% [markdown]
# Zgornji argumenti ostajajo fiksni, menjamo le število generacij (100, 1000) in velikost populacije (20, 100):

# %%
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 89624.9390040434

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 64058.945006051

# %%
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 47316.20466279582

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 36408.74108684091

# %% [markdown]
# Enak postopek naredimo še za primer **ulysses22**:

# %%
data = "ulysses22.txt"
dataPot = "ulysses22opt.txt"
    
lokacije = pr.preberi(data)
razdalje = pr.mestaGeo(lokacije)
najkrajsa = pr.najkrajsaConcord(dataPot)

# %% [markdown]
# Graf in dolžina najkrajše poti za primer **ulysses22**, dobljen s TSP Concord Solverjem:

# %%
pr.narisi(najkrajsa, lokacije)

# %%
pr.dolzinaPoti(najkrajsa, razdalje)
# Out:
# 7013.0

# %% [markdown]
# Zgornji argumenti ostajajo fiksni, menjamo le število generacij (100, 1000) in velikost populacije (20, 100):

# %%
CO = "OX"
k_turnir = 5
verj_mutacije = 0.005

# %%
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 8273.0

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 7314.0

# %%
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 8478.0

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.gaTsp(st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat, razdalje)))
pr.narisi(rezultat, lokacije)
# Out:
# Dolžina najkrajše poti: 7112.0

# %% [markdown]
# Različne parametre preizkusimo tudi na tretjem problemu **berlin52**, kjer dodamo še vsa tri možna križanja in algoritme ponavljamo po 20-krat:

# %%
data = "berlin52.txt"
dataPot = "berlin52opt.txt"
    
lokacije = pr.preberi(data)
razdalje = pr.mesta(lokacije)
najkrajsa = pr.najkrajsaConcord(dataPot)

# %%
pr.narisi(najkrajsa, lokacije)

# %%
pr.dolzinaPoti(najkrajsa, razdalje)
# Out:
# 7544.365901904087

# %%
st_ponovitev = 20
k_turnir = 5

# %% [markdown]
# Fiksna v tem primeru ostajata zgornja dva argumenta, spreminjamo pa verjetnost mutacije (0, 0.005, 0.04), velikost populacije (20, 100), število generacij (100, 1000) in vrsto metode križanja (CX, PMX, OX):

# %% [markdown]
# Začnemo z metodo CX:

# %%
CO = "CX"
verj_mutacije = 0
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat[1][0], razdalje)))
pr.narisi(rezultat[1][0], lokacije)
# Out:
# Dolžina najkrajše poti: 24365.538857518306

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat[1][0], razdalje)))
pr.narisi(rezultat[1][0], lokacije)
# Out:
# Dolžina najkrajše poti: 20187.495655088194

# %%
CO = "CX"
verj_mutacije = 0
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat[1][0], razdalje)))
pr.narisi(rezultat[1][0], lokacije)
# Out:
# Dolžina najkrajše poti: 24851.905851899537

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat[1][0], razdalje)))
pr.narisi(rezultat[1][0], lokacije)
# Out:
# Dolžina najkrajše poti: 19586.957717645524

# %% [markdown]
# Verjetnost mutacije spremenimo na 0.005 in postopek ponovimo:

# %%
CO = "CX"
verj_mutacije = 0.005
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat[1][0], razdalje)))
pr.narisi(rezultat[1][0], lokacije)
# Out:
# Dolžina najkrajše poti: 14548.748684787799

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat[1][0], razdalje)))
pr.narisi(rezultat[1][0], lokacije)
# Out:
# Dolžina najkrajše poti: 11723.1047639616

# %%
CO = "CX"
verj_mutacije = 0.005
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat[1][0], razdalje)))
pr.narisi(rezultat[1][0], lokacije)
# Out:
# Dolžina najkrajše poti: 9819.163192677623

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat[1][0], razdalje)))
pr.narisi(rezultat[1][0], lokacije)
# Out:
# Dolžina najkrajše poti: 9591.993968975761

# %% [markdown]
# Vzamemo še tretjo verjetnost mutacije, in sicer 0.04:

# %%
CO = "CX"
verj_mutacije = 0.04
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0.04, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat[1][0], razdalje)))
pr.narisi(rezultat[1][0], lokacije)
# Out:
# Dolžina najkrajše poti: 15848.917711215276

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0.04, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat[1][0], razdalje)))
pr.narisi(rezultat[1][0], lokacije)
# Out:
# Dolžina najkrajše poti: 12570.660506362703

# %%
CO = "CX"
verj_mutacije = 0.04
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0.04, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat[1][0], razdalje)))
pr.narisi(rezultat[1][0], lokacije)
# Out:
# Dolžina najkrajše poti: 14036.700146814099

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0.04, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat[1][0], razdalje)))
pr.narisi(rezultat[1][0], lokacije)
# Out:
# Dolžina najkrajše poti: 10842.375549131126

# %% [markdown]
# Zaključili smo s preizkušanjem argumentov na metodi CX, kot naslednjo vzemimo PMX:

# %%
CO = "PMX"
verj_mutacije = 0
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat[1][0], razdalje)))
pr.narisi(rezultat[1][0], lokacije)
# Out:
# Dolžina najkrajše poti: 20859.49531209348

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat[1][0], razdalje)))
pr.narisi(rezultat[1][0], lokacije)
# Out:
# Dolžina najkrajše poti: 15892.091857390866

# %%
CO = "PMX"
verj_mutacije = 0
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat[1][0], razdalje)))
pr.narisi(rezultat[1][0], lokacije)
# Out:
# Dolžina najkrajše poti: 20544.05708541531

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat[1][0], razdalje)))
pr.narisi(rezultat[1][0], lokacije)
# Out:
# Dolžina najkrajše poti: 15011.00933941573

# %% [markdown]
# Verjetnost mutacije zopet zamenjamo:

# %%
CO = "PMX"
verj_mutacije = 0.005
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat[1][0], razdalje)))
pr.narisi(rezultat[1][0], lokacije)
# Out:
# Dolžina najkrajše poti: 13973.016072506212

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat[1][0], razdalje)))
pr.narisi(rezultat[1][0], lokacije)
# Out:
# Dolžina najkrajše poti: 11166.844609956284

# %%
CO = "PMX"
verj_mutacije = 0.005
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat[1][0], razdalje)))
pr.narisi(rezultat[1][0], lokacije)
# Out:
# Dolžina najkrajše poti: 9524.05308862805

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat[1][0], razdalje)))
pr.narisi(rezultat[1][0], lokacije)
# Out:
# Dolžina najkrajše poti: 8776.658782095159

# %% [markdown]
# Vzamemo še tretjo verjetnost mutacije:

# %%
CO = "PMX"
verj_mutacije = 0.04
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0.04, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat[1][0], razdalje)))
pr.narisi(rezultat[1][0], lokacije)
# Out:
# Dolžina najkrajše poti: 15285.835495857482

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0.04, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat[1][0], razdalje)))
pr.narisi(rezultat[1][0], lokacije)
# Out:
# Dolžina najkrajše poti: 13732.823592800522

# %%
CO = "PMX"
verj_mutacije = 0.04
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0.04, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat[1][0], razdalje)))
pr.narisi(rezultat[1][0], lokacije)
# Out:
# Dolžina najkrajše poti: 14118.735181279462

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0.04, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat[1][0], razdalje)))
pr.narisi(rezultat[1][0], lokacije)
# Out:
# Dolžina najkrajše poti: 12848.075909937765

# %% [markdown]
# Celoten postopek ponovimo še na tretji metodi, OX:

# %%
CO = "OX"
verj_mutacije = 0
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat[1][0], razdalje)))
pr.narisi(rezultat[1][0], lokacije)
# Out:
# Dolžina najkrajše poti: 17330.05002175195

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat[1][0], razdalje)))
pr.narisi(rezultat[1][0], lokacije)
# Out:
# Dolžina najkrajše poti: 9755.065340908803

# %%
CO = "OX"
verj_mutacije = 0
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat[1][0], razdalje)))
pr.narisi(rezultat[1][0], lokacije)
# Out:
# Dolžina najkrajše poti: 18924.0203019158

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat[1][0], razdalje)))
pr.narisi(rezultat[1][0], lokacije)
# Out:
# Dolžina najkrajše poti: 10235.348658635436

# %% [markdown]
# Menjamo vrednost mutacije na 0.005:

# %%
CO = "OX"
verj_mutacije = 0.005
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat[1][0], razdalje)))
pr.narisi(rezultat[1][0], lokacije)
# Out:
# Dolžina najkrajše poti: 12864.325198548717

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat[1][0], razdalje)))
pr.narisi(rezultat[1][0], lokacije)
# Out:
# Dolžina najkrajše poti: 9830.896210556451

# %%
CO = "OX"
verj_mutacije = 0.005
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat[1][0], razdalje)))
pr.narisi(rezultat[1][0], lokacije)
# Out:
# Dolžina najkrajše poti: 9739.414551501997

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0.005, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat[1][0], razdalje)))
pr.narisi(rezultat[1][0], lokacije)
# Out:
# Dolžina najkrajše poti: 8737.45095992775

# %% [markdown]
# Še zadnja verjetnost mutacije:

# %%
CO = "OX"
verj_mutacije = 0.04
st_generacij = 100

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0.04, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat[1][0], razdalje)))
pr.narisi(rezultat[1][0], lokacije)
# Out:
# Dolžina najkrajše poti: 18324.84436499578

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0.04, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat[1][0], razdalje)))
pr.narisi(rezultat[1][0], lokacije)
# Out:
# Dolžina najkrajše poti: 15168.55676781616

# %%
CO = "OX"
verj_mutacije = 0.04
st_generacij = 1000

# %%
pop_velikost = 20
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0.04, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat[1][0], razdalje)))
pr.narisi(rezultat[1][0], lokacije)
# Out:
# Dolžina najkrajše poti: 16656.291660627812

# %%
pop_velikost = 100
pop = pr.populacija(pop_velikost, razdalje)
rezultat = pr.povprecje(st_ponovitev, st_generacij, razdalje, pop, 0.04, k_turnir, CO)
print("Dolžina najkrajše poti: " + str(pr.dolzinaPoti(rezultat[1][0], razdalje)))
pr.narisi(rezultat[1][0], lokacije)
# Out:
# Dolžina najkrajše poti: 16360.09758131356
